# %%
def define_image_config():
    return {
        "num_layers": 12,
        "input_dim": 3,
        "output_dim": 768,
        "patch_size": 16,
        "img_size": 224,
        "num_heads": 8,
        "mlp_hidden_dim": 3072,
        "dropout": 0.1
    }

# %%
def define_text_config():
    return {
        "num_layers": 12,
        "input_dim": 768,
        "output_dim": 768,
        "max_seq_len": 512,
        "num_heads": 8,
        "mlp_hidden_dim": 3072,
        "vocab_size": 49408,
        "dropout": 0.1,
    }

# %%
def define_proj_config():
    return {
        "input_dim": 768,
        "dropout": 0.1,
        "final_out": 512
    }
